# %% [markdown]
# $$\color{blue}{\Huge{\text{KRIVULJE}}}$$
#
# __Krivulja__ (parametrizirana krivulja) c u $\mathbb{R}^n$ je glatko preslikavanje s otvorenog intervala $I=<a,b> \subset\mathbb{R}$ u $\mathbb{R}^n$
# \\[\boxed{c:<a,b> \rightarrow\mathbb{R}^n}\\]
#
# Sada ćemo pokazati neke primjere krivulja, krenimo od najjednostavnijih.
#
# ### PRAVAC
#
# Eksplicitna jednadžba pravca dana je s $y=ax + b \ , \ a,b \in\mathbb{R}$, gdje $a$ označava koeficijent smjera, a $b$ odsječak na osi ordinata.

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 7))

x = np.arange(-5, 5)
ax.plot(x, x, 'g', label=r'$y=x$')
ax.plot(x, -x, color='orange', label=r'$y=-x$')
ax.plot(x, x+2, 'r', label=r'$y=x+2$')
ax.plot(x, x-2, 'b', label=r'$y=x-2$')
ax.legend(loc=6)

# %% [markdown]
# Funkcija sjeciste nam daje informaciju sijeku li se zadani pravci. Ukoliko se sijeku daje nam točku sjecišta.

# %%
import numpy as np
from sympy import *
from sympy.abc import x
from sympy import init_printing
init_printing()


def sjeciste(*p):

    for i in range(len(p)):
        for j in range(i+1, len(p)):
            eq = Eq(p[i], p[j])
            r = solve(eq, x)
            if(r == []):
                print("Pravaci {} i {} se ne sijeku!".format(p[i], p[j]))
            else:
                t = p[i].subs(x, r[0])
                print("Pravaci {} i {} se sijeku".format(p[i], p[j]))
                print("u točki ({}, {})".format(r[0], t))
sjeciste(x+2, -x)
# Out:
# Pravaci x + 2 i -x se sijeku
# u točki (-1, 1)

# %% [markdown]
# ### KRUŽNICA
# Kružnica je skup svih točaka u ravnini jednako udaljenih od zadane točke (središta). Krug je geometrijski lik omeđen kružnicom.
#
# Kružnica sa središtem u točki $S(p,q)$ i polumjerom $r>0$ određena je jednadžbom:
# $$(x-p)^2+(y-q)^2=r^2$$
#
# Parametarska jednadžba kružnice je $(\rho\in [0,2\pi], 0\leq r < +\infty)$:
# $$x=r\cos(\rho)$$ $$y=r\sin(\rho)$$
#
# Sljedeća slika prikazuje jediničnu kružnicu (r=1) sa središtem u ishodištu koordinatnog sustava (p=q=0):

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

t = np.linspace(0, 2 * np.pi, 100)
x1 = np.linspace(0, 1.0, 100)
y1 = np.linspace(0, 0, 100)
x2 = np.cos(t)
y2 = np.sin(t)

fig, ax = plt.subplots()
ax.plot(x2, y2, 'b')
ax.set_title('Kružnica', fontsize=15)
ax.axis('equal')
ax.scatter(0.0, 0.0, c='b')
ax.plot(x1, y1, 'r')
ax.text(0.0, -0.15, "S=(0,0)", fontsize=14)
ax.text(0.5, 0.05, "r=1", fontsize=14)
# Out:
# Text(0.5,0.05,'r=1')

# %% [markdown]
# ##### Presjek kružnica
#
# Kružnice $K(S,R)$ i $k(s,r)$:
# 1. Nemaju zajedničkih točaka ako i samo ako je: $\bar{Ss}> R + r$ ili $\bar{Ss}< R - r$
# 2. Imaju jednu i samo jednu zajedničku točku koja leži na zajedničkoj tangnti $\rightarrow \bar{Ss} = R + r$
# 3. Imaju dvije i samo dvije zajedničke točke koje leže na zajedničkoj tangenti $\rightarrow R - r < \bar{Ss} < R+r$

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(9, 6))


def presjek(x1, x2, y1, y2, r1, r2):
    rho = np.linspace(0, 2*np.pi, 100)
    X1 = r1*np.cos(rho)+x1
    Y1 = r1*np.sin(rho)+y1
    X2 = r2*np.cos(rho)+x2
    Y2 = r2*np.sin(rho)+y2
    d = np.sqrt((x1-x2)**2+(y1-y2)**2)
    print("Udaljenost središta je {}".format(d))
    maxi = max(r1, r2)
    mini = min(r1, r2)
    if(d > maxi + mini):
        print("Kružnice se ne sijeku!")
    elif(d < maxi - mini):
        print("Kružnica manjeg promjera je unutar kružnice večeg promjera!")
    elif(maxi - mini < d and d < maxi + mini):
        print("Sijeku se u točno dvije točke!")
    elif(d == maxi + mini):
        print("Sijeku se točno u jednoj točki!")

    ax.plot(X1, Y1, 'r')
    ax.plot(X2, Y2, 'b')
    ax.scatter(x1, y1, c='r')
    ax.scatter(x2, y2, c='b')
    ax.text(x1+0.03, y1-0.05, "S1", fontsize=14)
    ax.text(x2+0.03, y2-0.05, "S2", fontsize=14)
presjek(0, 1, 0, 1, 1, 1)
# Out:
# Udaljenost središta je 1.4142135623730951
# Sijeku se u točno dvije točke!

# %% [markdown]
# ##### Sfera
# Kružnice su ravninski presjeci sfere. __Sfera__ je savršeno okrugli geometrijski i kružni objekat u trodimenzionalnom prostoru. Slično definiciji kružnice, koja je dvodimenzionalna, sfera je matematički definirana kao skup svih točaka koji se nalaze na istoj udaljenosti $r>o$ od određene točke $S$ u trodimenzionalnom prostoru. $S$ je središte sfere, a $r$ polumjer ili radijus.
#
# Prikaz sfere u prostornim polarnim koordinatama $(0\leq\rho\leq 2\pi, 0\leq \theta \leq \pi, 0\leq r <+\infty):$
# $$ s(\theta,\rho)=(r\sin\theta\cos\rho, r\sin\rho\sin\theta, r\cos\theta) $$
#
# Sljedeća slika prikazuje jediničnu sferu (r=1) sa središtem u ishodištu koordinatnog sustava:

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

theta = np.linspace(0, 2*np.pi, 100)
rho = np.linspace(0, np.pi, 100)


def s(theta, rho):
    x = np.outer(np.cos(theta), np.sin(rho))
    y = np.outer(np.sin(theta), np.sin(rho))
    z = np.outer(np.ones(np.size(theta)), np.cos(rho))
    return x, y, z

x, y, z = s(theta, rho)
ax.plot_wireframe(x, y, z, rstride=9, cstride=9, color='blue')

# %% [markdown]
# __Tangencijalna ravnina__ sfere u njezinoj točki $T$ je ravnina koja prolazi tom točkom i okomita je na spojnicu $ST$, tj. pravac $ST$ je normala sfere u točki $T$.
#
# Sljedeća funkcija daje normalu sfere radijusa 2 :

# %%
from sympy.plotting import plot3d_parametric_surface
from sympy import *

u = Symbol('u')
v = Symbol('v')


def normala(s):
    s0 = s[0]
    s1 = s[1]
    s2 = s[2]

    du0 = diff(s0, u, 1)
    du1 = diff(s1, u, 1)
    du2 = diff(s2, u, 1)

    dv0 = diff(s0, v, 1)
    dv1 = diff(s1, v, 1)
    dv2 = diff(s2, v, 1)

    n1 = -du2*dv1
    n1 = simplify(n1)
    n2 = du2*dv0
    n2 = simplify(n2)
    n3 = du0*dv1 - du1*dv0
    n3 = simplify(n3)

    n = [n1, n2, n3]
    return n
x = 2*sin(u)*cos(v)
y = 2*sin(u)*sin(v)
z = 2*cos(u)
plot3d_parametric_surface(x, y, z, (u, 0, 2*pi), (v, 0, pi))
print("Normala je {}".format(normala([x, y, z])))
# Out:
# Normala je [4*sin(u)**2*cos(v), 4*sin(u)**2*sin(v), 2*sin(2*u)]

# %% [markdown]
# __Loksodroma__ je spirala na sferi. Na zemaljskoj kugli to je krivulja koja siječe sve meridijane pod jednakim kutom, od jednog pola do drugog.

# %%
from IPython.display import Image
Image(url="https://upload.wikimedia.org/"
      "wikipedia/commons/6/6e/KUGSPI-9_Loxodrome.gif")
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/6e/KUGSPI-9_Loxodrome.gif"/>

# %% [markdown]
# ##### CIKLOIDA
# Cikloida nastaje gibanjem kružnice po pravcu.

# %%
from IPython.display import Image
Image(url='https://upload.wikimedia.org/'
      'wikipedia/commons/6/69/Cycloid_f.gif')
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/69/Cycloid_f.gif"/>

# %% [markdown]
# ### Ruže

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 3, figsize=(10, 8))
alpha = 0.6

ax[0].spines['right'].set_color('none')
ax[0].spines['top'].set_color('none')
ax[0].xaxis.set_ticks_position('bottom')
ax[0].spines['bottom'].set_position(('data', 0))
ax[0].yaxis.set_ticks_position('left')
ax[0].spines['left'].set_position(('data', 0))


def prva(t, beta):
    return alpha*np.sin(t+beta)*np.sin(3*t), alpha*np.cos(t+beta)*np.sin(3*t)

ax[0].plot(*prva(np.linspace(0, np.pi, 100), np.pi/2), color='r')
ax[0].set_title("Ruža sa tri latice")

ax[1].spines['right'].set_color('none')
ax[1].spines['top'].set_color('none')
ax[1].xaxis.set_ticks_position('bottom')
ax[1].spines['bottom'].set_position(('data', 0))
ax[1].yaxis.set_ticks_position('left')
ax[1].spines['left'].set_position(('data', 0))

for beta in [0, np.pi/3]:
    ax[1].plot(*prva(np.linspace(0, np.pi, 100), beta),
               label='$\\beta={:.3f}$'.format(beta))
ax[1].set_title("Dvije ruže sa tri latice ")

ax[2].spines['right'].set_color('none')
ax[2].spines['top'].set_color('none')
ax[2].xaxis.set_ticks_position('bottom')
ax[2].spines['bottom'].set_position(('data', 0))
ax[2].yaxis.set_ticks_position('left')
ax[2].spines['left'].set_position(('data', 0))


def druga(t, beta):
    return alpha*np.sin(t+beta)*np.sin(2*t), alpha*np.cos(t+beta)*np.sin(2*t)

ax[2].plot(*druga(np.linspace(0, 2*np.pi, 100), np.pi/4), color='r')
ax[2].set_title("Ruža sa četiri latice")
# Out:
# Text(0.5,1,'Ruža sa četiri latice')

# %% [markdown]
# ### Prostorne krivulje
#
# Skup od $\infty^1$ neprekinuto povezanih točaka prostora, koje ne leže u jednoj ravnini, nazivamo __prostornom krivuljom__. Loksodroma je primjer jedne prostorne krivulje koju sam već pokazala. Sada ćemo vidjeti još neke primjere prostornih krivulja.
#
# ###### Prostorna kubna parabola

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

t = np.linspace(-3, 3, 100)
x = t
y = t**2
z = t**3

ax.plot(x, y, z, label='Prostorna kubna parabola')
ax.legend()

plt.show()

# %% [markdown]
# ###### Obična cilindrična spirala

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import matplotlib as mpl
import numpy as np
import math

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

t = np.linspace(-2, 14, 200)
z = t
y = np.sin(t)
x = np.cos(t)
ax.plot(x, y, z, label='Cilindrična spirala')
ax.legend()

plt.show()

# %% [markdown]
# ###### Vivijanijev prozor

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import axes3d
import numpy as np
import matplotlib.pyplot as plt

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
r = 3
t = np.linspace(-4*np.pi, 4*np.pi, 100)
x = r*(1 + np.cos(t))
y = r*np.sin(t)
z = r*2*np.sin(t/2)
ax.plot(x, y, z, label='Vivijanijev prozor')
ax.legend()

plt.show()

# %% [markdown]
# ## Primjena krivulja
#
# ### Gaussova krivulja
#
# Mnogi statističari prilikom svojih proračuna, bilo u korist istraživanja stanja tržišta ili ponašanja Egipatske rijeke Nila, koriste Gaussovu krivulju. Ona predstavlja standardnu, tzv. gaussovu tj. normalnu raspodjelu. Govori o prirodi nasumičnosti. Smisao je u tome da kad se stvari mijenjaju, pokušavaju ostati u blizini točke prosjeka i uspijevaju se raštrkati oko prosjeka po glatkoj krivulji.
# Grafički prikaz rezultata radi se na temelju distribucije frekvencija.

# %%
import matplotlib.pyplot as plt
import numpy as np

mi = 0
sigma = 1
s = np.random.normal(mi, sigma, 10000)

plt.figure(figsize=(8, 6))
count, bins, ignored = plt.hist(s, 30, normed=True, color='lightblue',
                                histtype='stepfilled')
plt.plot(bins, (1/(sigma * np.sqrt(2 * np.pi))) * np.exp(- (bins - mi)**2 /
         (2 * sigma**2)), lw=3, color='r')
plt.show()

# %% [markdown]
# Normalna raspodjela u potpunosti je definirana aritmetičkom sredinom i standardnom devijacijom. Aritmetička sredina određuje središte, a standardna devijacija širinu.
# Također, normalna raspodjela je simetrična.

# %%
from IPython.display import Image
Image(url='http://course.cau-edu.net.cn/course/'
      'Z0344/ch03/se01/slide/images/03.gif')
# Out:
# <img src="http://course.cau-edu.net.cn/course/Z0344/ch03/se01/slide/images/03.gif"/>

# %% [markdown]
# ## Krivulje u prirodi
#
# Sada ćemo dati neke primjere krivulja koje pronalazimo u prirodi.
#
# ### Spirala
#
# Spirala je, u matematici, krivulja koja se kružno udaljava (može se reći i: približava) od svog centra. Dvodimenzionalna spirala najlakše se opisuje preko polarnih koordinata, gdje je polumjer r kontinuirana monotona funkcija kuta θ. Kružnica se može smatrati posebnim slučajem spirale (funkcija nije striktno monotona, nego konstantna).
#
# ##### Logaritamska spirala
#
# Najprije je nacrtajmo u Kartezijevim i polarnim koordinatama, a zatim ćemo prikazati neke primjere iz prirode gdje je uočavamo.

# %%
import numpy as np
from matplotlib import pyplot as plt

a = 3
b = 0.1759
t = np.linspace(-2*np.pi, 2*np.pi, 100)


def spirala(t):
    x = a * np.exp(b * t) * np.cos(t)
    y = a * np.exp(b * t) * np.sin(t)
    return x, y

x, y = spirala(t)

fig, ax = plt.subplots(1, 1)
ax.plot(x, y)
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
plt.xticks([]), plt.yticks([])

plt.show()

# %%
from pylab import *

rc('grid', color='#aaaaaa', linewidth=1, linestyle='-')

figure(figsize=(6, 6))
ax = axes([0.1, 0.1, 0.8, 0.8], polar=True)

t = arange(-4*pi, 4*pi, .1)
polar(t, 1.19**t, linewidth=2)

xt, yt = xticks()[0], yticks()[0]
xticks(xt, ['' for q in range(len(xt))])
yticks(yt, ['' for q in range(len(yt))])

savefig('logarithmic_spiral.svg')

# %% [markdown]
# Poseban slučaj logaritamske spirale je __Fibonaccijeva spirala__. Ona se dobiva popločavanje Fibonaccijevim kvadratima (duljine stranica su Fibonaccijevi brojevi) i upisivanjem četvrtine kružnice u svaki kvadrat. Zanimljiva nam je jer se nalazi u različitim oblicima u prirodi. Prikažimo Fibonaccijevu spiralu.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.collections import PatchCollection
plt.rcdefaults()


# Definiramo rekurzivnu funkciju kojom dobivamo Fibonaccijeve brojeve.
def fib(n):
    if n < 2:
        return n
    else:
        return fib(n-1) + fib(n-2)


def label(xy, text, j):
    y = xy[1] - 0.025
    plt.text(xy[0], y, text, ha="center", family='sans-serif', size=j)

fig, ax = plt.subplots()
patches = []

xy = np.array([0, 0])
c = xy
i = 1
t = numpy.array([270, 0])

for j in range(1, 7+4):
    t += 90
    if i == 5:
        i = 1
    if i == 1:
        xy = xy + [-fib(j-2), fib(j-1)]
        c = c + [-fib(j-2), 0]
    if i == 2:
        xy = xy + [-fib(j), -fib(j-2)]
        c = c + [0, -fib(j-2)]
    elif i == 3:
        xy = xy + [0, -fib(j)]
        c = c + [fib(j-2), 0]
    elif i == 4:
        xy = xy + [fib(j-1), 0]
        c = c + [0, fib(j-2)]

    rect = mpatches.Wedge([c[0], c[1]], fib(j), t[0], t[1], ec="none")
    patches.append(rect)

    rect = mpatches.Rectangle([xy[0], xy[1]], fib(j), fib(j), ec="none")
    patches.append(rect)
    i += 1
    label(xy + [0.5 * fib(j), 0.5 * fib(j)], "%s" % fib(j), j * 2)

colors = np.linspace(0, 0, 0)
collection = PatchCollection(patches, cmap=plt.cm.hsv, alpha=0.9)
collection.set_array(np.array(colors))
ax.add_collection(collection)
plt.axis('equal')
plt.axis('off')
plt.grid('off')
plt.show()

# %% [markdown]
# Uz Fibonaccijevu spiralu često se veže pojam zlatnog reza.
# __Zlatni rez__ se često označava s grčkim slovom φ. Izraženo algebarski:
# $$\frac{a+b}{a} =\frac{a}{b} =\phi $$
# φ je pozitivno rješenje jednadžbe $$ \phi ^2 - \phi -1 =0 $$
# Stoga je: $$ \phi=\frac{1+\sqrt5}{2}\approx 1.61803\ldots $$

# %%
from IPython.display import Image
Image(url='http://heraznanje.com/wp-content/uploads/2016/05/'
      'GoldenFibonacci.jpg', width=500, height=500)
# Out:
# <img src="http://heraznanje.com/wp-content/uploads/2016/05/GoldenFibonacci.jpg" width="500" height="500"/>

# %% [markdown]
# Prikažimo φ kao red :

# %%
from sympy import factorial, var, Sum, oo, Rational
from sympy import init_printing
init_printing()

n = var('n')

red = Sum(((-1)**(n+1)*factorial(2*n+1)) /
          (factorial(n+2)*factorial(n)*4**(2*n+3)), (n, 0, oo))+Rational(13, 8)
red
# Out:
#   ∞
#  ____
#  ╲
#   ╲       n + 1  -2⋅n - 3
#    ╲  (-1)     ⋅4        ⋅(2⋅n + 1)!   13
#    ╱  ────────────────────────────── + ──
#   ╱            n!⋅(n + 2)!             8
#  ╱
#  ‾‾‾‾
# n = 0

# %% [markdown]
# Sada ćemo pokazati još neke zanimljive pojave zlatnog reza u prirodi.

# %%
from skimage import io

slika1 = io.imread('zlatni1.jpg')
io.imshow(slika1)
# Out:
# C:\Users\Kata\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter

plt.figure(figsize=(14, 8))

plt.subplot(1, 2, 1)
plt.imshow(gaussian_filter(img1, sigma=3))
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(gaussian_filter(img1, sigma=8))
plt.axis('off')
# Out:
# (-0.5, 699.5, 472.5, -0.5)

# %%
import matplotlib.pyplot as plt
from scipy.misc import imread
from scipy.ndimage.filters import gaussian_filter

plt.figure(figsize=(16, 10))
plt.subplot(1, 3, 1)
img2 = imread('zlatni1.jpg')
plt.imshow(img2)
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(gaussian_filter(img2, sigma=1))
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(gaussian_filter(img2, sigma=2))
plt.axis('off')
# Out:
# C:\Users\Kata\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   import sys
# (-0.5, 699.5, 472.5, -0.5)

# %%
from scipy.misc import imread
import matplotlib.pyplot as plt

cvijet = imread('cvijet.jpg')
plt.figure(figsize=(6, 5))
plt.imshow(cvijet)
plt.axis('off')
# Out:
# C:\Users\Kata\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# (-0.5, 599.5, 449.5, -0.5)

# %% [markdown]
# Na prikazanu sliku ('cvijet.jpg') primjenit ćemo Robertsov filter i Sobelov filter. Robertsov filter koristi se za obradu slike i računalnu viziju za otkrivanje rubova. Također, Sobelov filtar, koristi se za obradu slike i računalnu viziju, osobito unutar algoritama za otkrivanje rubova gdje stvara rubove s naglaskom na slici.

# %%
import matplotlib.pyplot as plt
from skimage import color
from skimage.filters import roberts, sobel

cvijet = color.rgb2gray(cvijet)

edge_roberts = roberts(cvijet)
edge_sobel = sobel(cvijet)

fig, ax = plt.subplots(ncols=2, sharex=True, sharey=True, figsize=(13, 8))

ax[0].imshow(edge_roberts, cmap=plt.cm.gray)
ax[0].set_title('Roberts otkrivanje rubova', fontsize=20)

ax[1].imshow(edge_sobel, cmap=plt.cm.gray)
ax[1].set_title('Sobel otkrivanje rubova', fontsize=20)

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()

# %%
from scipy.misc import imread
import matplotlib.pyplot as plt
from skimage.exposure import rescale_intensity
import numpy as np
from skimage.morphology import reconstruction

imag = imread('Hurricane.jpg')
imag = rescale_intensity(imag, in_range=(40, 200))

seed = np.copy(imag)
seed[1:-1, 1:-1] = imag.max()
mask = imag

filled = reconstruction(seed, mask, method='erosion')

seed = np.copy(imag)
seed[2:-1, 2:-1] = imag.min()
rec = reconstruction(seed, mask, method='dilation')

fig, ax = plt.subplots(1, 2, figsize=(8, 6), sharex=True, sharey=True,
                       subplot_kw={'adjustable': 'box-forced'})
ax = ax.ravel()

# Početna slika
ax[0].imshow(imag, cmap='gray')
ax[0].axis('off')

# Nakon popunjenja rupa
ax[1].imshow(filled, cmap='gray')
ax[1].axis('off')

plt.show()
# Out:
# C:\Users\Kata\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   import sys

# %% [markdown]
# ### Duljina luka krivulje
#
# Funkcija duljine luka krivulje $c$ od točke $c(t_0)$ je funkcija $s$ definirana ovako: $$ s(t)=\int_{t_0}^{t} ||c'(u)||du , t_0 \in I $$
#
# __Duljina luka__ krivulje $c:<a,b>\rightarrow\mathbb{R}^n$ je realan broj $$ s= \int_{a}^{b}||c'(u)||du$$
#
# __Primjer__ Odredite duljinu luka astroide $ c(t)=\left(\cos^3(t), \sin^3(t)\right), t \in  \left[ 0,2\pi \right> $

# %%
from scipy.integrate import quad
from numpy import cos, sin, sqrt
from math import pi


def norma(x):
    return (sqrt((cos(x))**6 + (sin(x))**6))


def duljina_luka(f, a, b):
    return quad(f, a, b)

duljina_luka(norma, 0, 2*pi)
# Out:
# (4.844224110273837, 1.733634707000876e-10)

# %% [markdown]
# ### Reparametrizacija krivulje
#
# Parametrizirana krivulja $ \bar{c}: \bar{I} \rightarrow \mathbb{R}^n$ naziva se __reparametrizacijom__ (parametrizirane) krivulje $ c:I \rightarrow\mathbb{R}^n$ ako postoji glatki difeomorfizam $ \phi:\bar{I}\rightarrow I$ za koji vrijedi $ \bar{c}=c\circ\phi $, tj. $$ \bar{c}(\bar{t})= c(\phi(\bar{t}))=c(t) ,  t \in I$$
#
# __Primjer__ Reparametrizirajte kružnicu $ c(t) = \left(1+ 2\cos(t), 3 + 2\sin(t)\right) , t \in \left[0,2\pi\right> $, duljinom luka.

# %%
from sympy import integrate, trigsimp, Symbol
import sympy as s
from sympy.functions import cos, sin, sqrt

x = Symbol('x')
s = integrate(sqrt((2*cos(x))**2+(2*sin(x))**2), x)
print("s(x) = ", s)

s = trigsimp(2*x*sqrt(sin(x)**2 + cos(x)**2))

# Pojednostavnili smo izraz koji dobijemo kad izračunamo integral.
print("Pojednostavljeno rjesenje integrala je s(x) = ", s)

# Imamo da je s(x)=2*x pa je x(s)=1/2*s.
s = Symbol('s')
x = 1.0/2*s


# Definiramo funkciju iz zadatka.
def fun(x):
    return (1 + 2*cos(x), 3 + 2*sin(x))


# Dobivamo reparametrizaciju duljinom luka.
def reparametrizacija(f, x):
    return f(x)

reparametrizacija(fun, x)
# Out:
# s(x) =  2*x*sqrt(sin(x)**2 + cos(x)**2)
# Pojednostavljeno rjesenje integrala je s(x) =  2*x
# (2⋅cos(0.5⋅s) + 1, 2⋅sin(0.5⋅s) + 3)

# %% [markdown]
# ### Regularne krivulje
#
# Krivulju $ c:I\rightarrow\mathbb{R}^n $ nazivamo __regularnom__ ako je $ c'(t)\not=0 , t \in I $. Točku krivulje za koju je $ c'(t)=0 $ nazivamo singularnom.
#
# __Primjer__ Ispitajte je li krivulja $ c(t)=\left( \sin^2(t), \cos^2(t) \right), t \in \left< \frac{\pi}{4}, \frac{3\pi}{4}\right>) $ regularna.

# %%
from sympy import Symbol, trigsimp, diff
from scipy.optimize import bisect
import scipy
from sympy import *
from sympy.abc import x

# Najprije deriviramo funkciju.
xx = diff(sin(x)**2, x)
yy = diff(cos(x)**2, x)

xx = trigsimp(2*sin(x)*cos(x))
print ('xx = ', xx)
yy = trigsimp(-2*sin(x)*cos(x))
print ('yy = ', yy)


# Je li derivacija različita od nule u svakoj točki na zadanom intervalu.
def pom1(x):
    y = scipy.sin(2*x)
    return y


def pom2(x):
    y = -(scipy.sin(2*x))
    return y

if(bisect(pom1, pi*1.0/4, pi*3.0/4) != 0 or
   bisect(pom2, pi*1.0/4, pi*3.0/4) != 0):
    print ("Postoje nultočke na zadanom intervalu, funkcija nije regularna!")
# Out:
# xx =  sin(2*x)
# yy =  -sin(2*x)
# Postoje nultočke na zadanom intervalu, funkcija nije regularna!
